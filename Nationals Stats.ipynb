# %%
import cPickle
import csv
import os
import re

import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "http://play.usaultimate.org"

# %%
if not os.path.isfile("match_urls.pkl"):
    # Get all match reports
    r = requests.get(BASE_URL + "/events/USA-Ultimate-D-I-College-Championships/schedule/Mens/College-x-College/")
    soup = BeautifulSoup(r.text)
    reports = soup.findAll("a", attrs={"href": re.compile("EventGameId")})
    match_urls = [report.attrs["href"] for report in reports]
    cPickle.dump(match_urls, file("match_urls.pkl", 'w'))

match_urls = cPickle.load(file("match_urls.pkl"))

# %%
class Stats(object):
    def __init__(self, name, goals, assists, ds, turns, team):
        self.name = name
        self.goals = goals
        self.assists = assists
        self.ds = ds
        self.turns = turns
        self.team = team

    def __add__(self, other):
        return Stats(self.name, self.goals+other.goals,
                self.assists+other.assists, self.ds+other.ds,
                self.turns+other.turns, self.team)

# %%
if not os.path.isfile("gamestats.pkl"):
    gamestats = {}

    # For each match report, pull out the stats
    for report_url in report_urls:
        r = requests.get(BASE_URL + report_url)
        gameid = re.search("GameId=(.*)", report_url).groups()[0]
        soup = BeautifulSoup(r.text)

        homediv = soup.find("div", attrs={"id": "home_team"})
        hometeam = homediv.find('span').text
        homestats = parsetable(homediv, hometeam)

        awaydiv = soup.find("div", attrs={"id": "away_team"})
        awayteam = awaydiv.find('span').text
        awaystats = parsetable(awaydiv, awayteam)

        gamestats[gameid] = {
            "home": {
                "name": hometeam,
                "stats": homestats
            },
            "away": {
                "name": awayteam,
                "stats": awaystats
            },
        }

    cPickle.dump(gamestats, file("gamestats.pkl"))

gamestats = cPickle.load(file("gamestats.pkl"))

# %%
with open('gamestats.csv', 'wb') as csvfile:
    c = csv.writer(csvfile, quoting=csv.QUOTE_MINIMAL)
    c.writerow(["game_id", "name", "team", "number", "goals", "assists", "ds", "turns"])
                      
    for gameid, game in gamestats.iteritems():
        hometeam = game["home"]["name"]
        homestats = game["home"]["stats"]
        awayteam = game["away"]["name"]
        awaystats = game["away"]["stats"]
        
        for _, stat in homestats.iteritems():
            number, name = stat.name.split(' ', 1)
            name = name.title()
            c.writerow([gameid, name, hometeam, number, stat.goals, stat.assists, stat.ds, stat.turns])
        for _, stat in awaystats.iteritems():
            number, name = stat.name.split(' ', 1)
            name = name.title()
            c.writerow([gameid, name, awayteam, number, stat.goals, stat.assists, stat.ds, stat.turns])

# %%
df = pd.read_csv('gamestats.csv')

# %%
df.head()
# Out:
#                                           game_id           name  \
# 0  rnQKIeOKxsAAy38278hLQwhyF2y3pCWPJvVN1eicsbM%3d     Nick Ochoa
# 1  rnQKIeOKxsAAy38278hLQwhyF2y3pCWPJvVN1eicsbM%3d       David Na
# 2  rnQKIeOKxsAAy38278hLQwhyF2y3pCWPJvVN1eicsbM%3d    David Smith
# 3  rnQKIeOKxsAAy38278hLQwhyF2y3pCWPJvVN1eicsbM%3d    Luke Yanker
# 4  rnQKIeOKxsAAy38278hLQwhyF2y3pCWPJvVN1eicsbM%3d  John Abuhamad
#
#             team number  goals  assists  ds  turns
# 0  Texas A&M (7)    #04      1        0   1      0
# 1  Texas A&M (7)    #11      3        3   0      0
# 2  Texas A&M (7)    #35      0        0   0      0
# 3  Texas A&M (7)    #14      0        0   0      0
# 4  Texas A&M (7)    #03      0        0   0      0
#
# [5 rows x 8 columns]
