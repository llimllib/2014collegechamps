# %%
import cPickle
import csv
import os
import re
import urllib

import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "http://play.usaultimate.org"

# %%
if not os.path.isfile("womens_match_urls.pkl"):
    # Get all match reports
    r = requests.get(BASE_URL + "/events/USA-Ultimate-D-I-College-Championships/schedule/Womens/College-x-College/")
    soup = BeautifulSoup(r.text)
    reports = soup.findAll("a", attrs={"href": re.compile("EventGameId")})
    match_urls = [report.attrs["href"] for report in reports]
    cPickle.dump(match_urls, file("womens_match_urls.pkl", 'w'))

match_urls = cPickle.load(file("womens_match_urls.pkl"))

# %%
class Stats(object):
    def __init__(self, name, goals, assists, ds, turns, team):
        self.name = name
        self.goals = goals
        self.assists = assists
        self.ds = ds
        self.turns = turns
        self.team = team

    def __add__(self, other):
        return Stats(self.name, self.goals+other.goals,
                self.assists+other.assists, self.ds+other.ds,
                self.turns+other.turns, self.team)

# %%
def parsetable(div, team):
    table = {}
    stats = div.find("table", attrs={"class": "global_table"})
    for row in stats.findAll("tr")[1:]:
        name, goals, assists, ds, turns = [r.text.strip() for r in row.findAll("td")]
        assert name, "Couldn't find name in row %s" % row
        table[name] = Stats(name, goals, assists, ds, turns, team)
    return table

if not os.path.isfile("womens_gamestats.pkl"):
    gamestats = {}

    # For each match report, pull out the stats
    for match_url in match_urls:
        r = requests.get(BASE_URL + match_url)
        gameid = re.search("GameId=(.*)", match_url).groups()[0]
        soup = BeautifulSoup(r.text)

        homediv = soup.find("div", attrs={"id": "home_team"})
        hometeam = homediv.find('span').text
        homestats = parsetable(homediv, hometeam)

        awaydiv = soup.find("div", attrs={"id": "away_team"})
        awayteam = awaydiv.find('span').text
        awaystats = parsetable(awaydiv, awayteam)

        gamestats[gameid] = {
            "home": {
                "name": hometeam,
                "stats": homestats
            },
            "away": {
                "name": awayteam,
                "stats": awaystats
            },
        }

    cPickle.dump(gamestats, file("womens_gamestats.pkl", 'w'))

gamestats = cPickle.load(file("womens_gamestats.pkl"))

# %%
def teamseed(team):
    team, seed = team.rsplit(" ", 1)
    seed = int(seed.strip("()"))
    return team, seed

with open('womens_gamestats.csv', 'wb') as csvfile:
    c = csv.writer(csvfile, quoting=csv.QUOTE_MINIMAL)
    c.writerow(["game_id", "name", "team", "seed", "number", "goals", "assists", "ds", "turns"])
                      
    for gameid, game in gamestats.iteritems():
        gameid = urllib.unquote(gameid)
        hometeam, homeseed = teamseed(game["home"]["name"])
        homestats = game["home"]["stats"]
        awayteam, awayseed = teamseed(game["away"]["name"])
        awaystats = game["away"]["stats"]
        
        for _, stat in homestats.iteritems():
            number, name = stat.name.split(' ', 1)
            number = number.strip("#")
            name = name.title()
            c.writerow([gameid, name, hometeam, homeseed, number, stat.goals, stat.assists, stat.ds, stat.turns])
        for _, stat in awaystats.iteritems():
            number, name = stat.name.split(' ', 1)
            number = number.strip("#")
            name = name.title()
            c.writerow([gameid, name, awayteam, awayseed, number, stat.goals, stat.assists, stat.ds, stat.turns])

# %%
df = pd.read_csv('womens_gamestats.csv')

# %%
df.head()
# Out:
#                                         game_id                 name  \
# 0  DClQY99QTof8NL7UWozAW+ukVEDkHu2hzh/qVs3/x9E=        Jamie Johnson
# 1  DClQY99QTof8NL7UWozAW+ukVEDkHu2hzh/qVs3/x9E=      Arielle Koshkin
# 2  DClQY99QTof8NL7UWozAW+ukVEDkHu2hzh/qVs3/x9E=          Emily Kampa
# 3  DClQY99QTof8NL7UWozAW+ukVEDkHu2hzh/qVs3/x9E=   Caroline Sheffield
# 4  DClQY99QTof8NL7UWozAW+ukVEDkHu2hzh/qVs3/x9E=  Lucia Childs-Walker
#
#                team  seed  number  goals  assists  ds  turns
# 0  Carleton College     6      63      0        0   0      0
# 1  Carleton College     6       4      1        0   2      1
# 2  Carleton College     6      23      0        0   0      0
# 3  Carleton College     6       8      1        0   0      0
# 4  Carleton College     6      10      0        1   0      4
#
# [5 rows x 9 columns]

# %%
totals = df[["name", "team", "number", "goals", "assists", "ds", "turns"]].groupby(["name", "team", "number"]).sum()
totals.sort_index(by="ds", ascending=False)
# Out:
#                                                     goals  assists  ds  turns
# name               team                     number
# Sonya Harris       Central Florida          23          6       40  24     38
# Mariel Hammond     Central Florida          12          6       18  13     25
# Cassandra Swafford Ohio State               14         10       29  12     17
# Noelle  Neason     California-Santa Barbara 21         13        7  12     13
# Michaela Fallon    Tufts                    11          5        7  12     12
# Kelly Gross        California-Santa Barbara 20          5       17  10     24
# Qxhna Titcomb      Tufts                    10          9       12  10     21
# Lisi Lohre         Colorado College         42         11       20  10     40
# Kathryn Flood      Northeastern             20          9        5  10     17
# Lisa Pitcaithley   California-Santa Barbara 26         15       26   9     13
# Elizabeth Jones    Northeastern             5           2       13   9     12
# Jesse Shofner      Oregon                   2          14       23   9      8
# Hannah Garfield    Tufts                    80          3        4   9      4
# Patricia Weicht    Colorado College         17         13        2   9      7
# Mira Donaldson     British Columbia         19          7       19   8     22
# Alika Johnston     Virginia                 13          4       30   8     18
# Jessie Bell        Victoria                 16          3        1   8      2
# Naomi Johnson      British Columbia         32          6        4   8      4
# Barbara Hoover     Washington               8          14       17   8      9
# Alexandra Hardesty Whitman                  25          2        2   8     13
# Hilary Vance       Stanford                 12          6        4   8      6
# Christina Mickle   Colorado                 19          2        2   7     13
# Joy Kang           California-Santa Barbara 16         10        8   7     16
# Caitlin Harley     Ohio State               8           6        9   7      3
# Michelle Chang     UCLA                     12          1       10   7     21
# Han Chen           UCLA                     25          3        8   7     19
# Lauren Franke      Ohio State               17         13        3   7      1
# Jacqueline Jarik   Michigan                 72          8        8   7      7
# Alexandra Ode      Oregon                   7           9        7   7     12
# Monisha White      Stanford                 14          1        8   6     27
# Kristen Pojunis    UCLA                     4           4        2   6      4
# Melissa Ellis      Northeastern             22          8       11   6     12
# Lucy Williams      Washington               12          3       17   6     12
# Margaret Zientek   Cornell                  22          4        3   6     14
# Molly Boyd         Washington               25         13        2   6      7
# Jenni-Lyn Ladutko  Northeastern             31          7        2   6      8
# Jennifer Brown     Victoria                 5           0        4   6     11
# Jenna Galletta     Ohio State               19          5        9   6      5
# Grace Lin          Northeastern             9           3        6   6     14
# Corinne Pingul     Whitman                  4           4        3   6      5
# Shayna Brock       Central Florida          8          16        5   6      7
# Theresa Zettner    Michigan                 14         18       17   6     20
# Chloe Rowse        Colorado College         6           0        7   6      9
# Julia Snyder       Carleton College         27          7       27   5     25
# Anne Rempel        Stanford                 15          2       10   5     10
# Olivia Bartruff    Oregon                   9          14        0   5      3
# Ahna Weeks         Carleton College         21          8        0   5      4
# Nicola Parker      Victoria                 77          1        3   5      6
# Alysia Letourneau  Washington               4          18        7   5      4
# Alyssa Abbey       Michigan                 1          13        1   5      1
# Andrea Fontenot    Oregon                   15          7        1   5      7
# Claire Revere      Whitman                  28         13       13   5     13
# Christina Baker    Kansas                   10          0       10   5     12
# Clare Frantz       Kansas                   12          7        5   5     10
# Corinne Dunwoody   Victoria                 13          1        6   5     13
# Hannah Henkin      Michigan                 37          2        5   5      8
# Kersten Barton     Carleton College         34          1        4   5     15
# Kellie Schueler    Stanford                 5           5        1   5      2
# Kate Scarth        Victoria                 8           5        6   5      5
# Abbie Abramovich   Western Washington       44          2       15   5     13
#                                                       ...      ... ...    ...
#
# [402 rows x 4 columns]
